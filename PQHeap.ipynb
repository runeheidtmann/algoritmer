# %% [markdown]
# <h3>Mål</h3>
# Det konkrete mål for del I af projektet er at implementere datastrukturen
# prioritetskø. Prioritetskøen vil blive brugt igen senere i del III af projektet.
# <h3>Opgaven</h3>
# Implementer bogens pseudo-kode for prioritetskøer i python
#
# <h3>Krav</h3>
# Filnavn: PQHeap.py
# implementer strukturen heap, som skal bestå af en liste af tal.
#
# funktioner i programmet:
# <ul>
#     <li><b>extractMin(A)</b> - som fjerner det element i prioritetskøen A, der har mindst prioritet og returnere det. Kan kun kaldes på en ikke-tom prioritetskø.</li>
#     <li><b>insert(A,e)</b> - som indsætter elementet e i prioritetskøen A/li>
#     <li><b>createEmptyPQ()</b>, der returnerer en ny, tom prioritetskø</li>
# </ul>

# %%
class MaxPQHeap:
    def __init__(self,A):
        self.A = self.buildMaxHeap(A)
    def parent(self, i):
        return (i - 1) // 2

    def left(self, i):
        return 2 * i + 1
    
    def right(self, i):
        return 2 * i + 2
    
    def maxHeapify(self, A, i):
        l = self.left(i)
        r = self.right(i)
    
        if l <= len(A)-1 and A[l] > A[i]:
            largest = l
        else:
            largest = i
        
        if  r <= len(A)-1 and A[r] > A[largest]:
            largest = r
        
        if largest != i:
            temp = A[i]
            A[i] = A[largest]
            A[largest] = temp
            return self.maxHeapify(A,largest)
        return A
    
    def buildMaxHeap(self,A):
        size = len(A)
        for i in range(size//2-1,-1,-1):
            A = self.maxHeapify(A,i)
#             print(i)
#             print(A)
        return A
    def extractMax(self):
        max = self.A[0]
        self.A[0] = self.A[len(self.A)-1]
        self.A.pop()
        self.A = self.maxHeapify(self.A,0)
        return max
    def maxHeapInsert(self,key):
        self.A.append(key)
        i = len(self.A)-1
        
        while i > 0 and self.A[self.parent(i)] < self.A[i]:
            temp = self.A[i]
            self.A[i] = self.A[self.parent(i)]
            self.A[self.parent(i)] = temp
            i = self.parent(i)
            print(i)
        
        return self.A

# %%
class MinPQHeap:
    def parent(self, i):
        return (i - 1) // 2

    def left(self, i):
        return 2 * i + 1
    
    def right(self, i):
        return 2 * i + 2
    
    def minHeapify(self, A, i):
        l = self.left(i)
        r = self.right(i)
    
        if l <= len(A)-1 and A[l] < A[i]:
            largest = l
        else:
            largest = i
        
        if  r <= len(A)-1 and A[r] < A[largest]:
            largest = r
        
        if largest != i:
            temp = A[i]
            A[i] = A[largest]
            A[largest] = temp
            return self.minHeapify(A,largest)
        return A
    def createEmptyPQ():
        return []
    
    def buildMinHeap(self,A):
        size = len(A)
        for i in range(size//2-1,-1,-1):
            A = self.minHeapify(A,i)
#             print(i)
#             print(A)
        return A
    def extractMin(self,A):
        min = A[0]
        A[0] = A[len(self.A)-1]
        A.pop()
        A = self.minHeapify(A,0)
        return min
    
    def insert(A,key):
        A.append(key)
        i = len(A)-1
        
        while i > 0 and A[self.parent(i)] > A[i]:
            temp = A[i]
            A[i] = A[self.parent(i)]
            A[self.parent(i)] = temp
            i = self.parent(i)
            print(i)
        
        return A

# %%
a = [4,1,3,2,16,9,10,14,8,7,25,55,66]

# %%
import sys

pq = MinPQHeap.createEmptyPQ()
a = [4,1,3,2,16,9,10,14,8,7,25,55,66]
n = 0
for line in a:
    MinPQHeap.insert(pq,line)
    n = n+1

print()
while n > 0:
    print(PQHeap.extractMin(pq))
    n = n-1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f5a60d9df8a1> in <module>
#       5 n = 0
#       6 for line in a:
# ----> 7     MinPQHeap.insert(pq,line)
#       8     n = n+1
#       9
#
# <ipython-input-18-ca090ca183b4> in insert(A, key)
#      48         i = len(A)-1
#      49
# ---> 50         while i > 0 and A[self.parent(i)] > A[i]:
#      51             temp = A[i]
#      52             A[i] = A[self.parent(i)]
#
# NameError: name 'self' is not defined
